# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

from sklearn import datasets
from sklearn.datasets import load_diabetes

#442 명의 당뇨병 환자 각각에 대해 10 개의 기준 변수, 연령, 성별, 체질량 지수, 평균 혈압 및 6 개의 혈청 측정 값
diabetes=load_diabetes()
#print(diabetes.keys())
#print(diabetes.feature_names)
diabetes_df = pd.DataFrame(diabetes.data , columns = diabetes.feature_names)
#print(diabetes.DESCR)

# %%
diabetes_df
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018118  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046879  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044528 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
diabetes_df.drop(['age','sex','s1','s2','s3','s4','s5','s6'],axis =1 , inplace=True)

# %%
bp_df = diabetes_df[['bp']]

# %%
bp_df
# Out:
#           bp
# 0    0.02187
# 1   -0.02633
# 2   -0.00567
# 3   -0.03666
# 4    0.02187
# ..       ...
# 437  0.05974
# 438 -0.06764
# 439  0.01728
# 440  0.00122
# 441 -0.08141
#
# [442 rows x 1 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
diabetes_df['y'] = diabetes.target

# %%
diabetes_df = diabetes_df.round(5)

# %%
diabetes_df.dtypes
# Out:
# bmi    float64
# bp     float64
# dtype: object

# %%
bp_df.shape
# Out:
# (442, 1)

# %%
bp_df.describe()
# Out:
#              bp
# count 442.00000
# mean    0.00000
# std     0.04762
# min    -0.11240
# 25%    -0.03666
# 50%    -0.00567
# 75%     0.03564
# max     0.13204

# %%
test_df = test_df[['bp']]*21

# %%
test_df.describe()
# Out:
#              bp
# count 442.00000
# mean    0.00000
# std     1.00000
# min    -2.36039
# 25%    -0.76979
# 50%    -0.11908
# 75%     0.74852
# max     2.77293

# %%
test_df
# Out:
#           bp
# 0    0.00104
# 1   -0.00125
# 2   -0.00027
# 3   -0.00175
# 4    0.00104
# ..       ...
# 437  0.00285
# 438 -0.00322
# 439  0.00082
# 440  0.00006
# 441 -0.00388
#
# [442 rows x 1 columns]

# %%
test_df[['bp']].max()
# Out:
# bp   0.00629
# dtype: float64

# %%
test_df[['bp']].min()
# Out:
# bp   -0.00535
# dtype: float64

# %%
test_df[['bp']].mean()
# Out:
# bp   0.00000
# dtype: float64

# %%
test_df[['bp']].median()
# Out:
# bp   -0.00027
# dtype: float64

# %%
test_df = test_df[['bp']] +

# %%
np.set_printoptions(suppress=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

from sklearn import datasets
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

for i in range(1,300):

diabetes=load_diabetes()
diabetes_df = pd.DataFrame(diabetes.data , columns = diabetes.feature_names)
bp_df = diabetes_df[['bp']]
bp_np = bp_df.to_numpy()
X = bp_np
bp_df_y_std = diabetes_df[['bp']]* A
bp_df_y = bp_df_y_std[['bp']] + B
scaler = StandardScaler()
scaler.fit(bp_df_y)
y = scaler.transform(bp_df_y)
MSE =  mean_squared_error(X, y)
RMSE = np.sqrt(MSE)
R2 = r2_score(X, y)
print(RMSE, R2)
# Out:
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.952407916735
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845502 -399.9524079167352
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845502 -399.9524079167351
# 0.9524348505845501 -399.952407916735
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.952407916735
# 0.9524348505845501 -399.952407916735
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.95243485058455 -399.95240791673496
# 0.95243485058455 -399.95240791673496
# 0.9524348505845502 -399.9524079167351
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.95240791673507
# 0.9524348505845501 -399.952407916735
# ...

# %%
bp_df_y.describe()
# Out:
#              bp
# count 442.00000
# mean  200.00000
# std    14.23810
# min   166.39252
# 25%   189.03972
# 50%   198.30449
# 75%   210.65751
# max   239.48122

# %%
X.flatten(), y.flatten()
# Out:
# (array([ 0.02187235, -0.02632783, -0.00567061, -0.03665645,  0.02187235,
#         -0.01944209, -0.01599922,  0.06662967, -0.04009932, -0.03321358,
#          0.00810087, -0.03321358, -0.00911348,  0.00810087, -0.01255635,
#          0.08040116,  0.04941532,  0.05630106, -0.03665645, -0.04009932,
#         -0.04354219,  0.00121513, -0.00911348,  0.03105334, -0.02288496,
#         -0.04009932, -0.02632783, -0.04009932, -0.07452802,  0.0631868 ,
#         -0.01944209, -0.08141377,  0.0287581 , -0.00222774, -0.05731367,
#         -0.04928031,  0.05285819, -0.05731367,  0.09761551, -0.07452802,
#          0.02187235, -0.10895673, -0.0148516 , -0.07108515,  0.00810087,
#          0.03220097, -0.03321358, -0.05731367,  0.01154374, -0.00567061,
#          0.01498661,  0.0287581 , -0.00567061,  0.07007254,  0.00810087,
#         -0.03665645, -0.02632783, -0.05042793,  0.03564384,  0.01154374,
#         -0.04009932, -0.0538708 , -0.04009932, -0.06075654, -0.04009932,
# ...

# %%
X = diabetes_df.drop(['y'],axis =1 , inplace=False)

# %%
y = diabetes_df[['y']].to_numpy().flatten()

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
# %matplotlib inline

importances = mutual_info_classif(X, y)
feat_importances = pd.Series(importances,diabetes_df.columns[0:len(diabetes_df.columns)-1])
feat_importances.plot(kind='barh',color='teal')
plt.show()

# %%
import seaborn as sns
# %matplotlib inline

cor = diabetes_df.corr()
plt.figure(figsize= (15,10))
sns.heatmap(cor,annot=True)

# %%
# Code source: Jaques Grobler
# License: BSD 3 clause

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
bp_df.describe()
# Out:
#              bp
# count 442.00000
# mean    0.00000
# std     0.04762
# min    -0.11240
# 25%    -0.03666
# 50%    -0.00567
# 75%     0.03564
# max     0.13204

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn

from sklearn import datasets
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

np.set_printoptions(suppress=True)

#for i in range(1,300):

diabetes=load_diabetes()
diabetes_df = pd.DataFrame(diabetes.data , columns = diabetes.feature_names)
bp_df = diabetes_df[['bp']]
bp_np = bp_df.to_numpy()
X = bp_np

# %%
bp_df_y_std = bp_df[['bp']]* 348
print(bp_df_y_std.max()-bp_df_y_std.min())
bp_df_y_std.describe()
# Out:
# bp   85.06645
# dtype: float64
#              bp
# count 442.00000
# mean    0.00000
# std    16.57143
# min   -39.11506
# 25%   -12.75644
# 50%    -1.97337
# 75%    12.40406
# max    45.95139

# %%
bp_df_y = bp_df_y_std[['bp']] + 77
bp_df_y.describe()
# Out:
#              bp
# count 442.00000
# mean   77.00000
# std    16.57143
# min    37.88494
# 25%    64.24356
# 50%    75.02663
# 75%    89.40406
# max   122.95139

# %%
scaler = StandardScaler()
scaler.fit(bp_df_y)
y = scaler.transform(bp_df_y)
MSE =  mean_squared_error(X, y)
RMSE = np.sqrt(MSE)
R2 = r2_score(X, y)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('drive/MyDrive/2021_하반기교육')

# %%
ls
# Out:
#  211117_tf.Variable.ipynb          DM_Assignment_1.ipynb
#  211123_visualize_day1.ipynb       DM_Assignment_2.ipynb
#  births.txt                        gapminder.tsv
#  CCTV_in_Seoul.csv                '제목 없는 설문지.gform'
#  data.zip                          Jeju2021.csv
#  day1003_ML_ANS.ipynb              ML1_01_Before.ipynb
#  day1004_ML_ANS.ipynb              ML1_02_knn.ipynb
#  day1004_ML.ipynb                  ML1_03_훈련세트와테스트세트.ipynb
#  day1101_2_ML.ipynb                ML1_04_before.ipynb
#  day1101_ML.ipynb                  ML1_05_iris_1.ipynb
#  day1104_ML.ipynb                  ML2_01_scaler.ipynb
#  day1202_릿지와라쏘_ML.ipynb       ML2_02_Data인코딩.ipynb
#  day1205_ML.ipynb                  ML2_03_교차검증.ipynb
#  day203_pandas.ipynb               ML2_04_성능평가.ipynb
#  day301_pandas.ipynb               ML3_01_Before.ipynb
#  day302_pandas.ipynb               ML4_01_before.ipynb
#  day402_Pandas_퀴즈2_1_ANS.ipynb   ML4_02_before.ipynb
# ...

# %%
df = pd.read_csv('dia_1213.csv')

# %%
df.describe()
# Out:
#        patient_number  cholesterol   glucose  ...  diastolic_bp     waist       hip
# count       390.00000    390.00000 390.00000  ...     390.00000 390.00000 390.00000
# mean        195.50000    207.23077 107.33846  ...      83.28974  37.86923  42.99231
# std         112.72755     44.66601  53.79819  ...      13.49819   5.76095   5.66434
# min           1.00000     78.00000  48.00000  ...      48.00000  26.00000  30.00000
# 25%          98.25000    179.00000  81.00000  ...      75.00000  33.00000  39.00000
# 50%         195.50000    203.00000  90.00000  ...      82.00000  37.00000  42.00000
# 75%         292.75000    229.00000 107.75000  ...      90.00000  41.00000  46.00000
# max         390.00000    443.00000 385.00000  ...     124.00000  56.00000  64.00000
#
# [8 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   patient_number   390 non-null    int64
#  1   cholesterol      390 non-null    int64
#  2   glucose          390 non-null    int64
#  3   hdl_chol         390 non-null    int64
#  4   chol_hdl_ratio   390 non-null    object
#  5   age              390 non-null    int64
#  6   gender           390 non-null    object
#  7   height           390 non-null    int64
#  8   weight           390 non-null    int64
#  9   bmi              390 non-null    object
#  10  systolic_bp      390 non-null    int64
#  11  diastolic_bp     390 non-null    int64
#  12  waist            390 non-null    int64
#  13  hip              390 non-null    int64
#  14  waist_hip_ratio  390 non-null    object
#  15  diabetes         390 non-null    object
# dtypes: int64(11), object(5)
# memory usage: 48.9+ KB

# %%
import seaborn as sns
# %matplotlib inline

cor = df.corr()
plt.figure(figsize= (15,10))
sns.heatmap(cor,annot=True)

# %%
# !pip install dataprep
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 10.3 MB/s
# ...
#      |████████████████████████████████| 158 kB 53.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 943 kB 24.6 MB/s
# ...
#      |████████████████████████████████| 719 kB 42.5 MB/s
# ...
#      |████████████████████████████████| 366 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 29.7 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 23.3 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 848 kB 31.6 MB/s
# ...
#      |████████████████████████████████| 271 kB 63.1 MB/s
# ...
#      |████████████████████████████████| 192 kB 58.8 MB/s
# ...
#      |████████████████████████████████| 160 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 54.4 MB/s
# ...
#      |████████████████████████████████| 49 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 34.2 MB/s
# ...
#      |████████████████████████████████| 743 kB 41.2 MB/s
# ...

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

from dataprep.eda import create_report
from dataprep.eda import plot_missing
from dataprep.eda import plot_correlation
from dataprep.eda import plot

from sklearn.model_selection import train_test_split

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report, roc_curve
from sklearn.model_selection import learning_curve, cross_val_score, GridSearchCV
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import RobustScaler,StandardScaler,MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('dia_1213.csv',decimal=",")
df = data.copy()
pd.set_option('display.max_row',df.shape[0])
pd.set_option('display.max_column',df.shape[1]) 
df.head()
# Out:
#    patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0               1          193       77        49         3.90000   19
# 1               2          146       79        41         3.60000   19
# 2               3          217       75        54         4.00000   20
# 3               4          226       97        70         3.20000   20
# 4               5          164       91        67         2.40000   20
#
#    gender  height  weight      bmi  systolic_bp  diastolic_bp  waist  hip  \
# 0  female      61     119 22.50000          118            70     32   38
# 1  female      60     135 26.40000          108            58     33   40
# 2  female      67     187 29.30000          110            72     40   45
# 3  female      64     114 19.60000          122            64     31   39
# 4  female      70     141 20.20000          122            86     32   39
#
#    waist_hip_ratio     diabetes
# 0          0.84000  No diabetes
# ...

# %%
df=data.copy()
pd.set_option('display.max_row',df.shape[0])
pd.set_option('display.max_column',df.shape[1]) 
df.head()
# Out:
#    patient_number  cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  \
# 0               1          193       77        49         3.90000   19
# 1               2          146       79        41         3.60000   19
# 2               3          217       75        54         4.00000   20
# 3               4          226       97        70         3.20000   20
# 4               5          164       91        67         2.40000   20
#
#    gender  height  weight      bmi  systolic_bp  diastolic_bp  waist  hip  \
# 0  female      61     119 22.50000          118            70     32   38
# 1  female      60     135 26.40000          108            58     33   40
# 2  female      67     187 29.30000          110            72     40   45
# 3  female      64     114 19.60000          122            64     31   39
# 4  female      70     141 20.20000          122            86     32   39
#
#    waist_hip_ratio     diabetes
# 0          0.84000  No diabetes
# ...

# %%
def encoding(df):
    code = {'female':1,
            'male':0,
            'No diabetes':1,
            'Diabetes':0
           }
    for col in df.select_dtypes('object'):
        df.loc[:,col]=df[col].map(code)        
    return df

def imputation(df):
    df = df.dropna(axis=0)
    return df

def feature_engineering(df):
    useless_columns = ['patient_number']
    df = df.drop(useless_columns,axis=1)
    return df

def preprocessing(df):
    df = encoding(df)
    df = feature_engineering(df)
    df = imputation(df)
    
    X = df.drop(['cholesterol','glucose','hdl_chol','chol_hdl_ratio','age','gender','height','systolic_bp','diastolic_bp','waist','hip','waist_hip_ratio','diabetes'],axis=1)
    y = df['diabetes']

    return df,X,y

# %%
df, X, y = preprocessing(df)
df.head()
# Out:
#    cholesterol  glucose  hdl_chol  chol_hdl_ratio  age  gender  height  \
# 0          193       77        49         3.90000   19       1      61
# 1          146       79        41         3.60000   19       1      60
# 2          217       75        54         4.00000   20       1      67
# 3          226       97        70         3.20000   20       1      64
# 4          164       91        67         2.40000   20       1      70
#
#    weight      bmi  systolic_bp  diastolic_bp  waist  hip  waist_hip_ratio  \
# 0     119 22.50000          118            70     32   38          0.84000
# 1     135 26.40000          108            58     33   40          0.83000
# 2     187 29.30000          110            72     40   45          0.89000
# 3     114 19.60000          122            64     31   39          0.79000
# 4     141 20.20000          122            86     32   39          0.82000
#
#    diabetes
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
X.describe()
# Out:
#          weight       bmi
# count 390.00000 390.00000
# mean  177.40769  28.77564
# std    40.40782   6.60091
# min    99.00000  15.20000
# 25%   150.25000  24.10000
# 50%   173.00000  27.80000
# 75%   200.00000  32.27500
# max   325.00000  55.80000

# %%
corr = df.corr(method='pearson').abs()

fig = plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='tab10', vmin=-1, vmax=+1)
plt.title('Pearson Correlation')
plt.show()

print (df.corr()['diabetes'].abs().sort_values())
# Out:
# gender            0.01553
# height            0.02347
# diastolic_bp      0.04935
# hdl_chol          0.12313
# hip               0.14379
# bmi               0.14527
# weight            0.16299
# waist_hip_ratio   0.17562
# systolic_bp       0.19860
# cholesterol       0.20426
# waist             0.22338
# chol_hdl_ratio    0.27299
# age               0.30199
# glucose           0.68908
# diabetes          1.00000
# Name: diabetes, dtype: float64

# %%
df = data.copy()
df,X,y=preprocessing(df)
df['diabetes'].value_counts(normalize=True) #Classes déséquilibrées
# Out:
# 1   0.84615
# 0   0.15385
# Name: diabetes, dtype: float64

# %%
# Class count
count_class_0, count_class_1 = df['diabetes'].value_counts()

# Divide by class
df_class_0 = df[df['diabetes'] == 1]
df_class_1 = df[df['diabetes'] == 0]

print(count_class_0)
print(count_class_1)
# Out:
# 330
# 60

# %%
df_class_0_under = df_class_0.sample(count_class_1,random_state=42)
df_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling:')
print(df_under['diabetes'].value_counts())

df_under['diabetes'].value_counts().plot(kind='bar', title='Count (target)');
# Out:
# Random under-sampling:
# 1    60
# 0    60
# Name: diabetes, dtype: int64

# %%
df_under.describe()
# Out:
#        cholesterol   glucose  hdl_chol  chol_hdl_ratio       age    gender  \
# count    120.00000 120.00000 120.00000       120.00000 120.00000 120.00000
# mean     216.35000 144.01667  49.06667         4.92583  51.91667   0.55833
# std       51.88540  79.36714  17.68337         2.21517  16.57252   0.49867
# min       78.00000  56.00000  12.00000         2.00000  20.00000   0.00000
# 25%      181.00000  85.00000  36.00000         3.30000  40.00000   0.00000
# 50%      210.50000 110.50000  46.00000         4.50000  53.00000   1.00000
# 75%      242.00000 189.25000  60.00000         5.85000  64.00000   1.00000
# max      443.00000 385.00000 114.00000        19.30000  91.00000   1.00000
#
#          height    weight       bmi  systolic_bp  diastolic_bp     waist  \
# count 120.00000 120.00000 120.00000    120.00000     120.00000 120.00000
# mean   65.80833 181.26667  29.56083    140.14167      83.44167  38.99167
# ...
